# %% [markdown]
# #

# %%
# Import libraries and packages.
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset
companies1 = pd.read_csv("E:\Data\Road To data Science\Datasets\Modified_Unicorn_Companies.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Muskan Saleh\AppData\Local\Temp\ipykernel_3368\3488665509.py:1: SyntaxWarning: invalid escape sequence '\D'
#   companies1 = pd.read_csv("E:\Data\Road To data Science\Datasets\Modified_Unicorn_Companies.csv")

# %%
# Run this cell so pandas displays all columns
pd.set_option('display.max_columns', None)
companies1.head()
# Out:
#      Company  Valuation Date Joined                         Industry  \
# 0  Bytedance        180  2017-04-07          Artificial intelligence
# 1     SpaceX        100  2012-12-01                            Other
# 2      SHEIN        100  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe         95  2014-01-23                          FinTech
# 4     Klarna         46  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
#display the columns datatypes
companies1.dtypes
# Out:
# Company             object
# Valuation            int64
# Date Joined         object
# Industry            object
# City                object
# Country/Region      object
# Continent           object
# Year Founded         int64
# Funding             object
# Select Investors    object
# dtype: object

# %%
# Apply necessary datatype conversions.
companies1['Date Joined'] = pd.to_datetime(companies1['Date Joined'])
companies1.dtypes
# Out:
# Company                     object
# Valuation                    int64
# Date Joined         datetime64[ns]
# Industry                    object
# City                        object
# Country/Region              object
# Continent                   object
# Year Founded                 int64
# Funding                     object
# Select Investors            object
# dtype: object

# %%
# Create the column Years To Unicorn.
companies1['Years To Unicorn'] = companies1['Date Joined'].dt.year - companies1['Year Founded']

# %%
companies1.head()
# Out:
#      Company  Valuation Date Joined                         Industry  \
# 0  Bytedance        180  2017-04-07          Artificial intelligence
# 1     SpaceX        100  2012-12-01                            Other
# 2      SHEIN        100  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe         95  2014-01-23                          FinTech
# 4     Klarna         46  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Years To Unicorn
# ...

# %%
#Input validation
#correctint bad data

companies1['Years To Unicorn'].describe()
# Out:
# count    1074.000000
# mean        7.013035
# std         5.331842
# min        -3.000000
# 25%         4.000000
# 50%         6.000000
# 75%         9.000000
# max        98.000000
# Name: Years To Unicorn, dtype: float64

# %%
# Isolate any rows where `Years To Unicorn` is negative
companies1[companies1['Years To Unicorn'] < 0]
# Out:
#       Company  Valuation Date Joined                      Industry      City  \
# 527  InVision          2  2017-11-01  Internet software & services  New York
#
#     Country/Region      Continent  Year Founded Funding  \
# 527  United States  North America          2020   $349M
#
#                                       Select Investors  Years To Unicorn
# 527  FirstMark Capital, Tiger Global Management, IC...                -3

# %%
# Replace InVision's `Year Founded` value with 2011
companies1.loc[companies1['Company']=='InVision','Year Founded'] = 2011
## Verify the change was made properly
companies1[companies1['Company']=='InVision']
# Out:
#       Company  Valuation Date Joined                      Industry      City  \
# 527  InVision          2  2017-11-01  Internet software & services  New York
#
#     Country/Region      Continent  Year Founded Funding  \
# 527  United States  North America          2011   $349M
#
#                                       Select Investors  Years To Unicorn
# 527  FirstMark Capital, Tiger Global Management, IC...                -3

# %%
# Recalculate all values in the `Years To Unicorn` column
companies1['Years To Unicorn'] = companies1['Date Joined'].dt.year - companies1['Year Founded']
# Verify that there are no more negative values in the column
companies1['Years To Unicorn'].describe()
# Out:
# count    1074.000000
# mean        7.021415
# std         5.323155
# min         0.000000
# 25%         4.000000
# 50%         6.000000
# 75%         9.000000
# max        98.000000
# Name: Years To Unicorn, dtype: float64

# %%
# List provided by the company of the expected industry labels in the data
industry_list = ['Artificial intelligence', 'Other','E-commerce & direct-to-consumer', 'Fintech',\
       'Internet software & services','Supply chain, logistics, & delivery', 'Consumer & retail',\
       'Data management & analytics', 'Edtech', 'Health', 'Hardware','Auto & transportation', \
        'Travel', 'Cybersecurity','Mobile & telecommunications']

# %%
# Check which values are in `Industry` but not in `industry_list`
set(companies1['Industry']) - set(industry_list)
# Out:
# {'Artificial Intelligence', 'Data management and analytics', 'FinTech'}

# %%
# 1. Create `replacement_dict`
replacement_dict = {'Artificial Intelligence' : 'Artificial intelligence', 
                    'Data management and analytics':'Data management & analytics', 
                    'FinTech':'Fintech'}

# 2. Replace the incorrect values in the `Industry` column
companies1['Industry'] = companies1['Industry'].replace(replacement_dict)
# 3. Verify that there are no longer any elements in `Industry` that are not in `industry_list`
set(companies1['Industry']) - set(industry_list)
# Out:
# set()

# %%
# Isolate rows of all companies that have duplicates
companies1[companies1.duplicated(subset=['Company'],keep=False)]
# Out:
#          Company  Valuation Date Joined                 Industry         City  \
# 385      BrewDog          2  2017-04-10        Consumer & retail     Aberdeen
# 386      BrewDog          2  2017-04-10        Consumer & retail     Aberdeen
# 510       ZocDoc          2  2015-08-20                   Health     New York
# 511       ZocDoc          2  2015-08-20                   Health          NaN
# 1031  SoundHound          1  2018-05-03  Artificial intelligence  Santa Clara
# 1032  SoundHound          1  2018-05-03                    Other  Santa Clara
#
#       Country/Region      Continent  Year Founded Funding  \
# 385   United Kingdom         Europe          2007   $233M
# 386    UnitedKingdom         Europe          2007   $233M
# 510    United States  North America          2007   $374M
# 511    United States  North America          2007   $374M
# 1031   United States  North America          2005   $215M
# 1032   United States  North America          2005   $215M
#
# ...

# %%
# Drop rows of duplicate companies after their first occurrence
companies1 = companies1.drop_duplicates(subset=['Company'],keep ='first')

# %%
#Convert numerical data to categorical data
# Create new `High Valuation` column
# Use qcut to divide Valuation into 'high' and 'low' Valuation groups
companies1['High Valuation'] = pd.qcut(companies1['Valuation'], 2, labels = ['low', 'high'])

# %%
#Convert categorical data to numerical data
companies1['Continent'].value_counts()
# Out:
# Continent
# North America    586
# Asia             310
# Europe           143
# South America     21
# Oceania            8
# Africa             3
# Name: count, dtype: int64

# %%
# Create numeric `Continent Number` column
continent_dict = {'North America':1,
                  'Asia':2,
                  'Europe':3,
                  'South America':4,
                  'Ocenia':5,
                  'Africa':6}
companies1['Continent Number'] = companies1['Continent'].replace(continent_dict)
companies1.head()
# Out:
#      Company  Valuation Date Joined                         Industry  \
# 0  Bytedance        180  2017-04-07          Artificial intelligence
# 1     SpaceX        100  2012-12-01                            Other
# 2      SHEIN        100  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe         95  2014-01-23                          Fintech
# 4     Klarna         46  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Years To Unicorn  \
# ...

# %%
# Convert Country/Region to numeric
# Create `Country/Region Numeric` column
# Create numeric categories for Country/Region
companies1['Company/Region Numeric'] = companies1['Country/Region'].astype('category').cat.codes
companies1.head()
# Out:
#      Company  Valuation Date Joined                         Industry  \
# 0  Bytedance        180  2017-04-07          Artificial intelligence
# 1     SpaceX        100  2012-12-01                            Other
# 2      SHEIN        100  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe         95  2014-01-23                          Fintech
# 4     Klarna         46  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Years To Unicorn  \
# ...

# %%
# Convert `Industry` to numeric data
# Create dummy variables with Industry values
industry_encoded = pd.get_dummies(companies1['Industry'] )

# Combine `companies` DataFrame with new dummy Industry columns
companies1 = pd.concat([companies1,industry_encoded],axis=1)

# %%
companies1.head()
# Out:
#      Company  Valuation Date Joined                         Industry  \
# 0  Bytedance        180  2017-04-07          Artificial intelligence
# 1     SpaceX        100  2012-12-01                            Other
# 2      SHEIN        100  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe         95  2014-01-23                          Fintech
# 4     Klarna         46  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Years To Unicorn  \
# ...
